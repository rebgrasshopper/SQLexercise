# %%
def greet():
    print('hi')

greet()
# Out:
# hi

# %%
a = 'abcdefghi'
a[::-1]
# Out:
# 'ihgfedcba'

# %%
sam = "Sam"
pam = "P"+ sam[1:]
print(sam, pam)
names = [sam, pam, "Graham"]
len(names[2])
# Out:
# Sam Pam
# 6

# %%
for name in names:
    print('Hello, {}'.format(name))
    print('{r:1.0f}'.format(r=len(name)))
    print(f"Hello, {name}")
# Out:
# Hello, Sam
# 3
# Hello, Sam
# Hello, Pam
# 3
# Hello, Pam
# Hello, Graham
# 6
# Hello, Graham

# %%
names.count("Sam")
# Out:
# 1
